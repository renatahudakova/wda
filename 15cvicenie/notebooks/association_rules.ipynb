# %% [markdown]
# ## Asociačné pravidlá - analýza nákupného košíka
#
# Jeden z druhov popisnej analýzy dát sú asociačné pravidlá. Predstavujú špecifický typ popisného modelu, ktorý je aplikovateľný na transakčných dátach. To sú dáta reprezentujúce napr. nákupné, alebo iné transakcie. Riadky v nich zodpovedajú jednotlivých transakciám (napr. jednotlivým nákupom) a stĺpce potom reprezentujú jednotlivé tovary. Hodnoty v jednotlivých stĺpcovh potom indikujú, či v sa v danom nákupe niektorý z tovarov vyskytol, alebo nie.
#
# Asociačné pravidlá potom používame na odhalenie častých kombinácií položiek v rámci množiny transakcií. Tento princíp nám teda pomôže identifikovať napr. položky, ktoré sa často nakupujú spoločne (odtiaľ aj odvodený názov - analýza nákupného košíka).
#
# Pre hľadanie asociačných pravidiel v Pythone potrebujeme najprv doinštalovať moduly obsahujúce potrebné algoritmy pre ich hľadanie. Keďže knižnica Scikit-learn takéto neobsahuje, doinštalujeme modul `mlxtend`, ktorý obsahuje algoritmus Apriori, často používaný pre hľadanie asociačných pravidiel.
#
# Pre inštaláciu v distribúcii Anaconda je potrebné sa prepnúť do domovskej aplikácie (Anaconda Navigator). V záložke `Environments` potom kliknite na trojuholníkový symbol pri položke `base (root)`. V nej zvoľte možnosť `Open Terminal` a v príkazovom riadku zadajte príkaz `pip install mlxtend`. Takto nainštalujeme modul a budeme ho môcť používať v skriptoch a Jupyter notebookoch.

# %%
import pandas as pd # importujeme pandas
from mlxtend.frequent_patterns import apriori # importujeme knižnice pre apriori algoritmus
from mlxtend.frequent_patterns import association_rules # importujeme knižnicu pre asociačné pravidlá

# %% [markdown]
# Ako ukážkový dataset použijeme dataset Online Retail, ktorý obsahuje záznamy z transakcií nákupov rôzneho tovaru prostredníctvom internetového obchodu v rôznych krajinách. Pre demonštračné účely je dataset používaný v tomto notebooku zredukovaný.
#
# Dáta načítame zo súboru a po vypísaní hlavičky vidíme štruktúru datasetu:
# * číslo faktúry
# * identifikačné číslo tovaru
# * názov tovaru
# * množstvo
# * dátum nákupu
# * cena za jednotku tovaru
# * ID zákazníka
# * krajina

# %%
data = pd.read_excel('../data/retail.xlsx') # načítame dáta zo súboru
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# Ako vidíme, dáta nemáme v požadovanej - transakčnej - podobe. Pre tieto účely musíme dáta predspracovať a zmeniť ich štruktúru. Upravíme medzery pre atribút `Description` a vyhodíme riadky, ktoré nemajú valídnu faktúru.

# %%
data['Description'] = data['Description'].str.strip() # orežeme nežiadúce medzery na začiatkoch a koncoch popisov
data.dropna(axis=0, subset=['InvoiceNo'], inplace=True) # odstránime riadky, ktoré majú chýbajúcu faktúru
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data['InvoiceNo'] = data['InvoiceNo'].astype('str') # zakódujeme číslo faktúry ako string
data = data[~data['InvoiceNo'].str.contains('C')] ####vlnovka je symbol negacie

# %% [markdown]
# Faktúru potom použijeme ako identifikátor transakcie - vstupné dáta transformujeme do dátového rámca `basket`, ktorý bude obsahovať riadky reprezentujúce nákupy (identifikované pomocou čísla faktúry) a jednotlivé atribúty budú reprezentovať počty nakúpených tovarov. Toto realizujeme pomocou zoskupenia (`groupBy`) podľa čísla faktúry, položky a množstva. Pre selekciu dát ešte môžeme zvoliť aj atribút charakterizujúci krajinu, a môžeme tak identifikovať časté kombinácie nákupov na rôznych trhoch.
# Výslednú tabuľku si môžeme pozrieť vypísaním hlavičky.

# %%
basket = (data[data['Country'] == "France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                          0.0                            0.0
# 536852                          0.0                            0.0
# 536974                          0.0                            0.0
# 537065                          0.0                            0.0
# 537463                          0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                                       0.0
# 536852                                       0.0
# 536974                                       0.0
# 537065                                       0.0
# 537463                                       0.0
#
# Description  12 PENCILS TALL TUBE RED RETROSPOT  4 TRADITIONAL SPINNING TOPS  \
# InvoiceNo
# 536370                                      0.0                          0.0
# 536852                                      0.0                          0.0
# 536974                                      0.0                          0.0
# 537065                                      0.0                          0.0
# 537463                                      0.0                          0.0
#
# Description  5 HOOK HANGER RED MAGIC TOADSTOOL  6 RIBBONS EMPIRE  \
# InvoiceNo
# 536370                                     0.0               0.0
# 536852                                     0.0               0.0
# 536974                                     0.0               0.0
# 537065                                    12.0               0.0
# 537463                                     0.0               0.0
#
# Description  6 RIBBONS RUSTIC CHARM  60 CAKE CASES DOLLY GIRL DESIGN  \
# InvoiceNo
# 536370                          0.0                              0.0
# 536852                          0.0                              0.0
# 536974                          0.0                              0.0
# 537065                          0.0                              0.0
# 537463                          0.0                              0.0
#
# Description  72 SWEETHEART FAIRY CAKE CASES  ...  WOODEN CROQUET GARDEN SET  \
# InvoiceNo                                    ...
# 536370                                  0.0  ...                        0.0
# 536852                                  0.0  ...                        0.0
# 536974                                  0.0  ...                        0.0
# 537065                                  0.0  ...                        0.0
# 537463                                  0.0  ...                        0.0
#
# Description  WOODEN SKITTLES GARDEN SET  WOODLAND  STICKERS  \
# InvoiceNo
# 536370                              0.0                 0.0
# 536852                              0.0                 0.0
# 536974                              0.0                 0.0
# 537065                              0.0                 0.0
# 537463                              0.0                12.0
#
# Description  WOODLAND CHARLOTTE BAG  WOODLAND DESIGN  COTTON TOTE BAG  \
# InvoiceNo
# 536370                          0.0                               0.0
# 536852                          0.0                               0.0
# 536974                          0.0                               0.0
# 537065                          0.0                               0.0
# 537463                         10.0                               0.0
#
# Description  WOODLAND PARTY BAG + STICKER SET  WRAP GREEN PEARS  \
# InvoiceNo
# 536370                                    0.0               0.0
# 536852                                    0.0               0.0
# 536974                                    0.0               0.0
# 537065                                    0.0               0.0
# 537463                                    0.0               0.0
#
# Description  WRAP I LOVE LONDON  WRAP RED APPLES  ZINC METAL HEART DECORATION
# InvoiceNo
# 536370                      0.0              0.0                          0.0
# 536852                      0.0              0.0                          0.0
# 536974                      0.0              0.0                          0.0
# 537065                      0.0              0.0                          0.0
# 537463                      0.0              0.0                          0.0
#
# [5 rows x 409 columns]

# %% [markdown]
# Pre jednoduššiu prácu s asociačnými pravidlami ešte dáta binarizujeme - jednotlivé hodnoty atribútov nám budú iba indikovať, či bola daná položka zakúpená alebo nie (počet nebudeme brať do úvahy). Preto pomocou jednoduchej funkcie transformujeme dáta. Zároveň vyhodíme aj atribút `POSTAGE` popisujúci poštovné.

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
basket_sets = basket.applymap(encode_units) ####aplikuje funkciu na kazdu
basket_sets.drop('POSTAGE', inplace=True, axis=1)
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                            0                              0
# 536852                            0                              0
# 536974                            0                              0
# 537065                            0                              0
# 537463                            0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                                         0
# 536852                                         0
# 536974                                         0
# 537065                                         0
# 537463                                         0
#
# Description  12 PENCILS TALL TUBE RED RETROSPOT  4 TRADITIONAL SPINNING TOPS  \
# InvoiceNo
# 536370                                        0                            0
# 536852                                        0                            0
# 536974                                        0                            0
# 537065                                        0                            0
# 537463                                        0                            0
#
# Description  5 HOOK HANGER RED MAGIC TOADSTOOL  6 RIBBONS EMPIRE  \
# InvoiceNo
# 536370                                       0                 0
# 536852                                       0                 0
# 536974                                       0                 0
# 537065                                       1                 0
# 537463                                       0                 0
#
# Description  6 RIBBONS RUSTIC CHARM  60 CAKE CASES DOLLY GIRL DESIGN  \
# InvoiceNo
# 536370                            0                                0
# 536852                            0                                0
# 536974                            0                                0
# 537065                            0                                0
# 537463                            0                                0
#
# Description  72 SWEETHEART FAIRY CAKE CASES  ...  WOODEN CROQUET GARDEN SET  \
# InvoiceNo                                    ...
# 536370                                    0  ...                          0
# 536852                                    0  ...                          0
# 536974                                    0  ...                          0
# 537065                                    0  ...                          0
# 537463                                    0  ...                          0
#
# Description  WOODEN SKITTLES GARDEN SET  WOODLAND  STICKERS  \
# InvoiceNo
# 536370                                0                   0
# 536852                                0                   0
# 536974                                0                   0
# 537065                                0                   0
# 537463                                0                   1
#
# Description  WOODLAND CHARLOTTE BAG  WOODLAND DESIGN  COTTON TOTE BAG  \
# InvoiceNo
# 536370                            0                                 0
# 536852                            0                                 0
# 536974                            0                                 0
# 537065                            0                                 0
# 537463                            1                                 0
#
# Description  WOODLAND PARTY BAG + STICKER SET  WRAP GREEN PEARS  \
# InvoiceNo
# 536370                                      0                 0
# 536852                                      0                 0
# 536974                                      0                 0
# 537065                                      0                 0
# 537463                                      0                 0
#
# Description  WRAP I LOVE LONDON  WRAP RED APPLES  ZINC METAL HEART DECORATION
# InvoiceNo
# 536370                        0                0                            0
# 536852                        0                0                            0
# 536974                        0                0                            0
# 537065                        0                0                            0
# 537463                        0                0                            0
#
# [5 rows x 408 columns]

# %% [markdown]
# Pre hľadanie asociačných pravidiel najprv identifikujeme tzv. frekventované položky. V tomto prípade to bude predstavovať zoznam často nakupovaných položiek (samostatne, nie spolu), ktorý bude doprevádzaný informáciou o ich podpore (`support`) - tzn. podieli transakcií, v ktorých sa daná položka vyskytuje spomedzi všetkých transakcií. Pri vytváraní zoznamu týchto položie môžeme podporu použiť ako parameter pre orezanie množstva identifikovaných vzorov.

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.1, use_colnames=True) ####mnozina frekventovanych poloziek
frequent_itemsets.head()
# Out:
#     support                        itemsets
# 0  0.135135    (ALARM CLOCK BAKELIKE GREEN)
# 1  0.135135     (ALARM CLOCK BAKELIKE PINK)
# 2  0.135135      (ALARM CLOCK BAKELIKE RED)
# 3  0.108108    (ASSORTED COLOUR MINI CASES)
# 4  0.162162  (BAKING SET 9 PIECE RETROSPOT)

# %% [markdown]
# Z frekventovaných položiek potom vygenerujeme asociačné pravidlá v tvare `IF` predpoklady (`antecenteds`) `THEN` závery (`consequents`). K jednotlivým pravidlám potom knižnica vypíše aj podporu daného pravidla (podporu predpokladu, záveru a aj celého pravidla), spoľahlivosť (`confidence`) alebo `lift` pravidla.

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#                                            antecedents  \
# 0                         (ALARM CLOCK BAKELIKE GREEN)
# 1                          (ALARM CLOCK BAKELIKE PINK)
# 2                         (ALARM CLOCK BAKELIKE GREEN)
# 3                           (ALARM CLOCK BAKELIKE RED)
# 4                          (ALARM CLOCK BAKELIKE PINK)
# 5                           (ALARM CLOCK BAKELIKE RED)
# 6                           (RED RETROSPOT MINI CASES)
# 7                         (ASSORTED COLOUR MINI CASES)
# 8                    (CIRCUS PARADE CHILDRENS EGG CUP)
# 9                  (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 10                          (RED RETROSPOT MINI CASES)
# 11                             (EDWARDIAN PARASOL RED)
# 12                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 13                                 (GUMBALL COAT RACK)
# 14                  (LUNCH BOX WITH CUTLERY RETROSPOT)
# 15                            (JAM MAKING SET PRINTED)
# 16                     (PLASTERS IN TIN CIRCUS PARADE)
# 17                            (JAM MAKING SET PRINTED)
# 18                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 19                            (JAM MAKING SET PRINTED)
# 20                            (JAM MAKING SET PRINTED)
# 21               (SET OF 2 TEA TOWELS APPLE AND PEARS)
# 22                 (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 23                            (JAM MAKING SET PRINTED)
# 24                           (LUNCH BAG RED RETROSPOT)
# 25                                (LUNCH BAG WOODLAND)
# 26                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 27                  (LUNCH BOX WITH CUTLERY RETROSPOT)
# 28                          (RED RETROSPOT MINI CASES)
# 29                  (LUNCH BOX WITH CUTLERY RETROSPOT)
# ..                                                 ...
# 218                           (JAM MAKING SET PRINTED)
# 219              (SET OF 2 TEA TOWELS APPLE AND PEARS)
# 220  (PLASTERS IN TIN CIRCUS PARADE, RED RETROSPOT ...
# 221  (PLASTERS IN TIN CIRCUS PARADE, STRAWBERRY LUN...
# 222  (STRAWBERRY LUNCH BOX WITH CUTLERY, RED RETROS...
# 223  (PLASTERS IN TIN CIRCUS PARADE, RED RETROSPOT ...
# 224  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 225  (RED RETROSPOT MINI CASES, PLASTERS IN TIN WOO...
# 226  (STRAWBERRY LUNCH BOX WITH CUTLERY, PLASTERS I...
# 227  (PLASTERS IN TIN CIRCUS PARADE, RED RETROSPOT ...
# 228  (PLASTERS IN TIN CIRCUS PARADE, STRAWBERRY LUN...
# 229  (RED RETROSPOT MINI CASES, STRAWBERRY LUNCH BO...
# 230                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 231                    (PLASTERS IN TIN CIRCUS PARADE)
# 232                         (RED RETROSPOT MINI CASES)
# 233                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 234  (STRAWBERRY LUNCH BOX WITH CUTLERY, PLASTERS I...
# 235  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...
# 236  (STRAWBERRY LUNCH BOX WITH CUTLERY, RED RETROS...
# 237  (PLASTERS IN TIN SPACEBOY, STRAWBERRY LUNCH BO...
# 238  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...
# 239  (STRAWBERRY LUNCH BOX WITH CUTLERY, PLASTERS I...
# 240  (RED RETROSPOT MINI CASES, PLASTERS IN TIN WOO...
# 241  (PLASTERS IN TIN SPACEBOY, STRAWBERRY LUNCH BO...
# 242  (PLASTERS IN TIN SPACEBOY, RED RETROSPOT MINI ...
# 243  (RED RETROSPOT MINI CASES, STRAWBERRY LUNCH BO...
# 244                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 245                         (PLASTERS IN TIN SPACEBOY)
# 246                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 247                         (RED RETROSPOT MINI CASES)
#
#                                            consequents  antecedent support  \
# 0                          (ALARM CLOCK BAKELIKE PINK)            0.135135
# 1                         (ALARM CLOCK BAKELIKE GREEN)            0.135135
# 2                           (ALARM CLOCK BAKELIKE RED)            0.135135
# 3                         (ALARM CLOCK BAKELIKE GREEN)            0.135135
# 4                           (ALARM CLOCK BAKELIKE RED)            0.135135
# 5                          (ALARM CLOCK BAKELIKE PINK)            0.135135
# 6                         (ASSORTED COLOUR MINI CASES)            0.270270
# 7                           (RED RETROSPOT MINI CASES)            0.108108
# 8                  (STRAWBERRY LUNCH BOX WITH CUTLERY)            0.108108
# 9                    (CIRCUS PARADE CHILDRENS EGG CUP)            0.189189
# 10                             (EDWARDIAN PARASOL RED)            0.270270
# 11                          (RED RETROSPOT MINI CASES)            0.108108
# 12                                 (GUMBALL COAT RACK)            0.216216
# 13                  (PLASTERS IN TIN WOODLAND ANIMALS)            0.135135
# 14                            (JAM MAKING SET PRINTED)            0.189189
# 15                  (LUNCH BOX WITH CUTLERY RETROSPOT)            0.135135
# 16                            (JAM MAKING SET PRINTED)            0.243243
# 17                     (PLASTERS IN TIN CIRCUS PARADE)            0.135135
# 18                            (JAM MAKING SET PRINTED)            0.216216
# 19                  (PLASTERS IN TIN WOODLAND ANIMALS)            0.135135
# 20               (SET OF 2 TEA TOWELS APPLE AND PEARS)            0.135135
# 21                            (JAM MAKING SET PRINTED)            0.135135
# 22                            (JAM MAKING SET PRINTED)            0.189189
# 23                 (STRAWBERRY LUNCH BOX WITH CUTLERY)            0.135135
# 24                                (LUNCH BAG WOODLAND)            0.189189
# 25                           (LUNCH BAG RED RETROSPOT)            0.135135
# 26                  (LUNCH BOX WITH CUTLERY RETROSPOT)            0.216216
# 27                  (PLASTERS IN TIN WOODLAND ANIMALS)            0.189189
# 28                  (LUNCH BOX WITH CUTLERY RETROSPOT)            0.270270
# 29                          (RED RETROSPOT MINI CASES)            0.189189
# ..                                                 ...                 ...
# 218  (PLASTERS IN TIN WOODLAND ANIMALS, LUNCH BOX W...            0.135135
# 219  (PLASTERS IN TIN WOODLAND ANIMALS, JAM MAKING ...            0.135135
# 220                (STRAWBERRY LUNCH BOX WITH CUTLERY)            0.108108
# 221                         (RED RETROSPOT MINI CASES)            0.108108
# 222                    (PLASTERS IN TIN CIRCUS PARADE)            0.135135
# 223                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.108108
# 224  (RED RETROSPOT MINI CASES, STRAWBERRY LUNCH BO...            0.135135
# 225  (PLASTERS IN TIN CIRCUS PARADE, STRAWBERRY LUN...            0.135135
# 226  (PLASTERS IN TIN CIRCUS PARADE, RED RETROSPOT ...            0.162162
# 227  (STRAWBERRY LUNCH BOX WITH CUTLERY, PLASTERS I...            0.162162
# 228  (RED RETROSPOT MINI CASES, PLASTERS IN TIN WOO...            0.108108
# 229  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...            0.135135
# 230  (PLASTERS IN TIN CIRCUS PARADE, RED RETROSPOT ...            0.216216
# 231  (STRAWBERRY LUNCH BOX WITH CUTLERY, RED RETROS...            0.243243
# 232  (PLASTERS IN TIN CIRCUS PARADE, STRAWBERRY LUN...            0.270270
# 233  (PLASTERS IN TIN CIRCUS PARADE, RED RETROSPOT ...            0.189189
# 234                         (RED RETROSPOT MINI CASES)            0.108108
# 235                (STRAWBERRY LUNCH BOX WITH CUTLERY)            0.108108
# 236                         (PLASTERS IN TIN SPACEBOY)            0.135135
# 237                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.108108
# 238  (RED RETROSPOT MINI CASES, STRAWBERRY LUNCH BO...            0.135135
# 239  (PLASTERS IN TIN SPACEBOY, RED RETROSPOT MINI ...            0.162162
# 240  (PLASTERS IN TIN SPACEBOY, STRAWBERRY LUNCH BO...            0.135135
# 241  (RED RETROSPOT MINI CASES, PLASTERS IN TIN WOO...            0.108108
# 242  (STRAWBERRY LUNCH BOX WITH CUTLERY, PLASTERS I...            0.135135
# 243  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...            0.135135
# 244  (PLASTERS IN TIN SPACEBOY, STRAWBERRY LUNCH BO...            0.216216
# 245  (STRAWBERRY LUNCH BOX WITH CUTLERY, RED RETROS...            0.189189
# 246  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...            0.189189
# 247  (STRAWBERRY LUNCH BOX WITH CUTLERY, PLASTERS I...            0.270270
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              0.135135  0.135135    1.000000  7.400000  0.116874         inf
# 1              0.135135  0.135135    1.000000  7.400000  0.116874         inf
# 2              0.135135  0.135135    1.000000  7.400000  0.116874         inf
# 3              0.135135  0.135135    1.000000  7.400000  0.116874         inf
# 4              0.135135  0.135135    1.000000  7.400000  0.116874         inf
# 5              0.135135  0.135135    1.000000  7.400000  0.116874         inf
# 6              0.108108  0.108108    0.400000  3.700000  0.078890    1.486486
# 7              0.270270  0.108108    1.000000  3.700000  0.078890         inf
# 8              0.189189  0.108108    1.000000  5.285714  0.087655         inf
# 9              0.108108  0.108108    0.571429  5.285714  0.087655    2.081081
# 10             0.108108  0.108108    0.400000  3.700000  0.078890    1.486486
# 11             0.270270  0.108108    1.000000  3.700000  0.078890         inf
# 12             0.135135  0.108108    0.500000  3.700000  0.078890    1.729730
# 13             0.216216  0.108108    0.800000  3.700000  0.078890    3.918919
# 14             0.135135  0.108108    0.571429  4.228571  0.082542    2.018018
# 15             0.189189  0.108108    0.800000  4.228571  0.082542    4.054054
# 16             0.135135  0.108108    0.444444  3.288889  0.075237    1.556757
# 17             0.243243  0.108108    0.800000  3.288889  0.075237    3.783784
# 18             0.135135  0.135135    0.625000  4.625000  0.105917    2.306306
# 19             0.216216  0.135135    1.000000  4.625000  0.105917         inf
# 20             0.135135  0.108108    0.800000  5.920000  0.089847    4.324324
# 21             0.135135  0.108108    0.800000  5.920000  0.089847    4.324324
# 22             0.135135  0.108108    0.571429  4.228571  0.082542    2.018018
# 23             0.189189  0.108108    0.800000  4.228571  0.082542    4.054054
# 24             0.135135  0.108108    0.571429  4.228571  0.082542    2.018018
# 25             0.189189  0.108108    0.800000  4.228571  0.082542    4.054054
# 26             0.189189  0.135135    0.625000  3.303571  0.094229    2.162162
# 27             0.216216  0.135135    0.714286  3.303571  0.094229    2.743243
# 28             0.189189  0.108108    0.400000  2.114286  0.056976    1.351351
# 29             0.270270  0.108108    0.571429  2.114286  0.056976    1.702703
# ..                  ...       ...         ...       ...       ...         ...
# 218            0.108108  0.108108    0.800000  7.400000  0.093499    4.459459
# 219            0.108108  0.108108    0.800000  7.400000  0.093499    4.459459
# 220            0.189189  0.108108    1.000000  5.285714  0.087655         inf
# 221            0.270270  0.108108    1.000000  3.700000  0.078890         inf
# 222            0.243243  0.108108    0.800000  3.288889  0.075237    3.783784
# 223            0.216216  0.108108    1.000000  4.625000  0.084733         inf
# 224            0.135135  0.108108    0.800000  5.920000  0.089847    4.324324
# 225            0.108108  0.108108    0.800000  7.400000  0.093499    4.459459
# 226            0.162162  0.108108    0.666667  4.111111  0.081812    2.513514
# 227            0.162162  0.108108    0.666667  4.111111  0.081812    2.513514
# 228            0.135135  0.108108    1.000000  7.400000  0.093499         inf
# 229            0.135135  0.108108    0.800000  5.920000  0.089847    4.324324
# 230            0.108108  0.108108    0.500000  4.625000  0.084733    1.783784
# 231            0.135135  0.108108    0.444444  3.288889  0.075237    1.556757
# 232            0.108108  0.108108    0.400000  3.700000  0.078890    1.486486
# 233            0.108108  0.108108    0.571429  5.285714  0.087655    2.081081
# 234            0.270270  0.108108    1.000000  3.700000  0.078890         inf
# 235            0.189189  0.108108    1.000000  5.285714  0.087655         inf
# 236            0.189189  0.108108    0.800000  4.228571  0.082542    4.054054
# 237            0.216216  0.108108    1.000000  4.625000  0.084733         inf
# 238            0.135135  0.108108    0.800000  5.920000  0.089847    4.324324
# 239            0.135135  0.108108    0.666667  4.933333  0.086194    2.594595
# 240            0.108108  0.108108    0.800000  7.400000  0.093499    4.459459
# 241            0.135135  0.108108    1.000000  7.400000  0.093499         inf
# 242            0.162162  0.108108    0.800000  4.933333  0.086194    4.189189
# 243            0.135135  0.108108    0.800000  5.920000  0.089847    4.324324
# 244            0.108108  0.108108    0.500000  4.625000  0.084733    1.783784
# 245            0.135135  0.108108    0.571429  4.228571  0.082542    2.018018
# 246            0.108108  0.108108    0.571429  5.285714  0.087655    2.081081
# 247            0.108108  0.108108    0.400000  3.700000  0.078890    1.486486
#
# [248 rows x 9 columns]

# %% [markdown]
# Pri veľkom množstve pravidiel je samozrejme možné prehľadávať a orezávať vygenerované pravidlá pomocou formovania podmienok a kritérií pre zobrazovanie pravidiel. Napr. príklad nižšie demonštruje zobrazenie len tých pravidiel, ktorých podpora je väčšia ako 0.2 a spoľahlivosť väčšia ako 0.9.

# %%
rules[ (rules['support'] >= 0.15) & (rules['confidence'] >= 0.8) ]
# Out:
#                             antecedents                         consequents  \
# 69  (STRAWBERRY LUNCH BOX WITH CUTLERY)  (PLASTERS IN TIN WOODLAND ANIMALS)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 69            0.189189            0.216216  0.162162    0.857143  3.964286
#
#     leverage  conviction
# 69  0.121256    5.486486
